# %%
import pandas as pd
import ast
from modules.utils import plt_utils

# %%
CASE_NAME: str = "bgl-cw-gemma2-9b"

# %% [markdown]
# ## Log Embedding Model(LEM) Training Metrics

# %%
# Log Embed Model Training History
lem_history_df = pd.read_csv(f"./output/{CASE_NAME}/lem/history.csv")
lem_history_df["eval_cm"] = lem_history_df["eval_cm"].apply(ast.literal_eval)
lem_fig = plt_utils.get_train_history_png(lem_history_df)
lem_history_df.head()
# Out:
#    epoch  train_mins  eval_mins  train_loss  eval_loss  train_accuracy  \
# 0      1    0.016667        0.0    0.358499   0.262523        0.909091
# 1      2    0.016667        0.0    0.232487   0.230350        0.988636
# 2      3    0.016667        0.0    0.220143   0.204333        0.988636
# 3      4    0.016667        0.0    0.202359   0.199481        1.000000
# 4      5    0.016667        0.0    0.200392   0.198967        1.000000
#
#    train_f1  train_precision  train_recall            train_cm  eval_accuracy  \
# 0  0.909091         0.930233      0.888889  [[40, 5], [3, 40]]       0.972973
# 1  0.989011         0.978261      1.000000  [[45, 0], [1, 42]]       0.972973
# 2  0.989011         0.978261      1.000000  [[45, 0], [1, 42]]       1.000000
# 3  1.000000         1.000000      1.000000  [[45, 0], [0, 43]]       1.000000
# 4  1.000000         1.000000      1.000000  [[45, 0], [0, 43]]       1.000000
#
#    eval_f1  eval_precision  eval_recall            eval_cm
# 0      0.8        0.666667          1.0  [[2, 0], [1, 34]]
# 1      0.8        0.666667          1.0  [[2, 0], [1, 34]]
# 2      1.0        1.000000          1.0  [[2, 0], [0, 35]]
# 3      1.0        1.000000          1.0  [[2, 0], [0, 35]]
# 4      1.0        1.000000          1.0  [[2, 0], [0, 35]]

# %% [markdown]
# ## Anomaly Detection LLM(ADLLM) Training Metrics

# %%
# Anomaly Detection LLM Training History
adllm_history_df = pd.read_csv(f"./output/{CASE_NAME}/adllm/history.csv")
adllm_history_df["eval_cm"] = adllm_history_df["eval_cm"].apply(ast.literal_eval)
adllm_fig = plt_utils.get_train_history_png(adllm_history_df)
adllm_history_df.head()
# Out:
#    epoch  train_mins  eval_mins  train_loss  eval_accuracy  eval_f1  \
# 0      1    0.166667        0.0    0.497268            1.0      1.0
# 1      2    0.166667        0.0    0.084649            1.0      1.0
# 2      3    0.166667        0.0    0.045311            1.0      1.0
# 3      4    0.166667        0.0    0.027748            1.0      1.0
# 4      5    0.166667        0.0    0.007340            1.0      1.0
#
#    eval_precision  eval_recall           eval_cm
# 0             1.0          1.0  [[7, 0], [0, 3]]
# 1             1.0          1.0  [[7, 0], [0, 3]]
# 2             1.0          1.0  [[7, 0], [0, 3]]
# 3             1.0          1.0  [[7, 0], [0, 3]]
# 4             1.0          1.0  [[7, 0], [0, 3]]
